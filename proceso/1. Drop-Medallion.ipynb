-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
dbutils.widgets.text("nameContainer","bronze")
dbutils.widgets.text("nameStorage","datlkeempresa")
dbutils.widgets.text("catalogo","catalog_ut_smartdata")

-- %%
%python

nameContainer = dbutils.widgets.get("nameContainer")
nameStorage = dbutils.widgets.get("nameStorage")
catalogo = dbutils.widgets.get("catalogo")

ruta = f"abfss://{nameContainer}@{nameStorage}.dfs.core.windows.net"
print(ruta)

-- %% [markdown]
-- ### Eliminacion tablas Bronze

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS catalog_empresa.bronze.palyer;
DROP TABLE IF EXISTS catalog_empresa.bronze.palyer_attributes;
DROP TABLE IF EXISTS catalog_empresa.silver.player_attributes;
DROP TABLE IF EXISTS catalog_empresa.golden.player_attributes;

-- %% [markdown]
-- ### Eliminacion tablas Silver

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS catalog_empresa.silver.circuits_transformed;

-- %% [markdown]
-- ### Eliminacion tablas Golden

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS catalog_empresa.golden.golden_raced_partitioned;

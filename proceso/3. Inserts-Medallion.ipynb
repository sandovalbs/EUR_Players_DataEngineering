-- %%
%python
dbutils.widgets.removeAll()

-- %%
create widget text storageLocation default "abfss://unit-catalog@adlsmardata0912.dfs.core.windows.net";
create widget text catalogo default "catalog_ut_smartdata";

-- %%
use catalog ${catalogo}

-- %% [markdown]
-- ###INSERTS BRONZE

-- %%
INSERT INTO ${catalogo}.bronze.CLIENTES VALUES
(1, 'Anthony', 'anthony@example.com', 'Peru'),
(2, 'Lucía', 'lucia@example.com', 'Colombia'),
(3, 'Carlos', 'carlos@example.com', 'México'),
(4, 'Ana', 'ana@example.com', 'Argentina'),
(5, 'Miguel', 'miguel@example.com', 'Chile'),
(6, 'Sofía', 'sofia@example.com', 'España'),
(7, 'Jorge', 'jorge@example.com', 'Ecuador'),
(8, 'Valentina', 'valentina@example.com', 'Peru'),
(9, 'Pedro', 'pedro@example.com', 'Uruguay'),
(10, 'Laura', 'laura@example.com', 'Paraguay'),
(11, 'Marcos', 'marcos@example.com', 'Venezuela'),
(12, 'Camila', 'camila@example.com', 'Peru'),
(13, 'Ricardo', 'ricardo@example.com', 'México'),
(14, 'Diana', 'diana@example.com', 'Colombia'),
(15, 'Andrés', 'andres@example.com', 'Chile'),
(16, 'Paula', 'paula@example.com', 'España'),
(17, 'Gonzalo', 'gonzalo@example.com', 'Argentina'),
(18, 'Fernanda', 'fernanda@example.com', 'Peru'),
(19, 'Sebastián', 'sebastian@example.com', 'Ecuador'),
(20, 'Natalia', 'natalia@example.com', 'México');

INSERT INTO ${catalogo}.bronze.VENTAS VALUES
(1, 1, '2024-01-01', 120.50),
(2, 2, '2024-01-02', 250.00),
(3, 3, '2024-01-03', 175.25),
(4, 4, '2024-01-04', 310.00),
(5, 5, '2024-01-05', 450.00),
(6, 6, '2024-01-06', 125.00),
(7, 7, '2024-01-07', 600.50),
(8, 8, '2024-01-08', 90.00),
(9, 9, '2024-01-09', 230.00),
(10, 10, '2024-01-10', 320.40),
(11, 11, '2024-01-11', 80.30),
(12, 12, '2024-01-12', 410.00),
(13, 13, '2024-01-13', 270.00),
(14, 14, '2024-01-14', 330.30),
(15, 15, '2024-01-15', 180.50),
(16, 16, '2024-01-16', 220.00),
(17, 17, '2024-01-17', 300.00),
(18, 18, '2024-01-18', 95.00),
(19, 19, '2024-01-19', 150.75),
(20, 20, '2024-01-20', 275.60);

INSERT INTO ${catalogo}.bronze.PRODUCTOS VALUES
(1, 'Laptop', 'Tecnología', 1500.00),
(2, 'Teléfono', 'Tecnología', 800.00),
(3, 'Tablet', 'Tecnología', 600.00),
(4, 'Monitor', 'Accesorios', 300.00),
(5, 'Teclado', 'Accesorios', 50.00),
(6, 'Mouse', 'Accesorios', 40.00),
(7, 'Silla ergonómica', 'Oficina', 200.00),
(8, 'Escritorio', 'Oficina', 350.00),
(9, 'Webcam', 'Accesorios', 100.00),
(10, 'Impresora', 'Oficina', 250.00),
(11, 'Auriculares', 'Tecnología', 120.00),
(12, 'Parlantes', 'Accesorios', 180.00),
(13, 'Smartwatch', 'Tecnología', 220.00),
(14, 'Router', 'Redes', 90.00),
(15, 'Disco SSD', 'Almacenamiento', 150.00),
(16, 'Disco HDD', 'Almacenamiento', 100.00),
(17, 'Cámara digital', 'Fotografía', 400.00),
(18, 'Tripié', 'Fotografía', 70.00),
(19, 'Micrófono', 'Accesorios', 130.00),
(20, 'Luz LED', 'Accesorios', 60.00);

-- %% [markdown]
-- ###INSERTS SILVER

-- %%
INSERT INTO ${catalogo}.silver.VENTAS_LIMPIAS VALUES
(1, 1, '2024-02-01', 130.00),
(2, 2, '2024-02-02', 220.00),
(3, 3, '2024-02-03', 305.75),
(4, 4, '2024-02-04', 150.50),
(5, 5, '2024-02-05', 275.00),
(6, 6, '2024-02-06', 320.30),
(7, 7, '2024-02-07', 410.00),
(8, 8, '2024-02-08', 500.00),
(9, 9, '2024-02-09', 180.00),
(10, 10, '2024-02-10', 95.50),
(11, 11, '2024-02-11', 215.00),
(12, 12, '2024-02-12', 330.60),
(13, 13, '2024-02-13', 145.00),
(14, 14, '2024-02-14', 270.00),
(15, 15, '2024-02-15', 390.00),
(16, 16, '2024-02-16', 155.50),
(17, 17, '2024-02-17', 290.75),
(18, 18, '2024-02-18', 305.00),
(19, 19, '2024-02-19', 110.00),
(20, 20, '2024-02-20', 240.00);

INSERT INTO ${catalogo}.silver.CLIENTES_VALIDOS VALUES
(1, 'Anthony', 'anthony@example.com', 'Peru', true),
(2, 'Lucía', 'lucia@example.com', 'Colombia', true),
(3, 'Carlos', 'carlos@example.com', 'México', true),
(4, 'Ana', 'ana@example.com', 'Argentina', false),
(5, 'Miguel', 'miguel@example.com', 'Chile', true),
(6, 'Sofía', 'sofia@example.com', 'España', true),
(7, 'Jorge', 'jorge@example.com', 'Ecuador', false),
(8, 'Valentina', 'valentina@example.com', 'Peru', true),
(9, 'Pedro', 'pedro@example.com', 'Uruguay', true),
(10, 'Laura', 'laura@example.com', 'Paraguay', true),
(11, 'Marcos', 'marcos@example.com', 'Venezuela', true),
(12, 'Camila', 'camila@example.com', 'Peru', false),
(13, 'Ricardo', 'ricardo@example.com', 'México', true),
(14, 'Diana', 'diana@example.com', 'Colombia', true),
(15, 'Andrés', 'andres@example.com', 'Chile', true),
(16, 'Paula', 'paula@example.com', 'España', true),
(17, 'Gonzalo', 'gonzalo@example.com', 'Argentina', false),
(18, 'Fernanda', 'fernanda@example.com', 'Peru', true),
(19, 'Sebastián', 'sebastian@example.com', 'Ecuador', true),
(20, 'Natalia', 'natalia@example.com', 'México', true);

INSERT INTO ${catalogo}.silver.DETALLE_PRODUCTOS VALUES
(1, 'Laptop', 'Tecnología', 1500.00, 10),
(2, 'Teléfono', 'Tecnología', 800.00, 25),
(3, 'Tablet', 'Tecnología', 600.00, 15),
(4, 'Monitor', 'Accesorios', 300.00, 20),
(5, 'Teclado', 'Accesorios', 50.00, 100),
(6, 'Mouse', 'Accesorios', 40.00, 120),
(7, 'Silla ergonómica', 'Oficina', 200.00, 8),
(8, 'Escritorio', 'Oficina', 350.00, 5),
(9, 'Webcam', 'Accesorios', 100.00, 30),
(10, 'Impresora', 'Oficina', 250.00, 12),
(11, 'Auriculares', 'Tecnología', 120.00, 40),
(12, 'Parlantes', 'Accesorios', 180.00, 25),
(13, 'Smartwatch', 'Tecnología', 220.00, 18),
(14, 'Router', 'Redes', 90.00, 50),
(15, 'Disco SSD', 'Almacenamiento', 150.00, 70),
(16, 'Disco HDD', 'Almacenamiento', 100.00, 60),
(17, 'Cámara digital', 'Fotografía', 400.00, 9),
(18, 'Tripié', 'Fotografía', 70.00, 30),
(19, 'Micrófono', 'Accesorios', 130.00, 20),
(20, 'Luz LED', 'Accesorios', 60.00, 45);

-- %% [markdown]
-- ###INSERTS GOLDEN

-- %%
INSERT INTO ${catalogo}.golden.KPIS_VENTAS VALUES
('2024-01-01', 1500.00, 75.00),
('2024-01-02', 2000.00, 80.00),
('2024-01-03', 1800.00, 72.00),
('2024-01-04', 2200.00, 88.00),
('2024-01-05', 1700.00, 68.00),
('2024-01-06', 2500.00, 100.00),
('2024-01-07', 1900.00, 76.00),
('2024-01-08', 2100.00, 84.00),
('2024-01-09', 2300.00, 92.00),
('2024-01-10', 1600.00, 64.00),
('2024-01-11', 1750.00, 70.00),
('2024-01-12', 1850.00, 74.00),
('2024-01-13', 1950.00, 78.00),
('2024-01-14', 2050.00, 82.00),
('2024-01-15', 2150.00, 86.00),
('2024-01-16', 2250.00, 90.00),
('2024-01-17', 2400.00, 96.00),
('2024-01-18', 2550.00, 102.00),
('2024-01-19', 2600.00, 104.00),
('2024-01-20', 2700.00, 108.00);

INSERT INTO ${catalogo}.golden.SEGMENTOS_CLIENTES VALUES
(1, 'Alto valor', 15000.00),
(2, 'Medio valor', 7500.00),
(3, 'Bajo valor', 2500.00),
(4, 'Alto valor', 12000.00),
(5, 'Medio valor', 6800.00),
(6, 'Bajo valor', 3000.00),
(7, 'Alto valor', 13500.00),
(8, 'Medio valor', 7200.00),
(9, 'Bajo valor', 2800.00),
(10, 'Medio valor', 6500.00),
(11, 'Alto valor', 14000.00),
(12, 'Bajo valor', 2000.00),
(13, 'Medio valor', 7600.00),
(14, 'Alto valor', 15500.00),
(15, 'Bajo valor', 1800.00),
(16, 'Medio valor', 7000.00),
(17, 'Alto valor', 16000.00),
(18, 'Bajo valor', 2300.00),
(19, 'Medio valor', 6900.00),
(20, 'Alto valor', 14500.00);

-- %% [markdown]
-- ###INSERTS EXPLORATORY

-- %%
INSERT INTO ${catalogo}.exploratory.EXPERIMENTOS VALUES
(1, 'Clasificación de clientes por edad', 'Éxito'),
(2, 'Predicción de ventas con regresión lineal', 'Parcialmente exitoso'),
(3, 'Clusterización KMeans de productos', 'Éxito'),
(4, 'Modelo de recomendación de productos', 'Fallo'),
(5, 'Red neuronal para clasificación de imágenes', 'Éxito'),
(6, 'Análisis de sentimientos de reseñas', 'Éxito'),
(7, 'Detección de fraudes con árboles de decisión', 'Parcialmente exitoso'),
(8, 'Regresión logística para churn', 'Fallo'),
(9, 'Análisis de patrones de consumo', 'Éxito'),
(10, 'Optimización de precios dinámica', 'Parcialmente exitoso'),
(11, 'Segmentación de clientes con DBSCAN', 'Éxito'),
(12, 'Pruebas con redes neuronales recurrentes', 'Fallo'),
(13, 'Modelado predictivo de inventario', 'Éxito'),
(14, 'Reconocimiento de voz con CNNs', 'Parcialmente exitoso'),
(15, 'Análisis de cohortes para retención', 'Éxito'),
(16, 'Clasificación de correos como spam', 'Éxito'),
(17, 'Modelado del comportamiento del usuario', 'Parcialmente exitoso'),
(18, 'Generación de texto con GPT', 'Éxito'),
(19, 'Simulación de escenarios de demanda', 'Éxito'),
(20, 'Predicción de clima con modelos ARIMA', 'Fallo');

INSERT INTO ${catalogo}.exploratory.PRUEBAS_MODELOS_EXT VALUES
(1, 'Random Forest', 0.87, '2024-01-01'),
(2, 'XGBoost', 0.91, '2024-01-02'),
(3, 'Regresión Lineal', 0.75, '2024-01-03'),
(4, 'SVM', 0.82, '2024-01-04'),
(5, 'KNN', 0.70, '2024-01-05'),
(6, 'Árbol de decisión', 0.78, '2024-01-06'),
(7, 'Red Neuronal', 0.93, '2024-01-07'),
(8, 'Logistic Regression', 0.80, '2024-01-08'),
(9, 'LSTM', 0.88, '2024-01-09'),
(10, 'Naive Bayes', 0.76, '2024-01-10'),
(11, 'CNN', 0.90, '2024-01-11'),
(12, 'LightGBM', 0.89, '2024-01-12'),
(13, 'AdaBoost', 0.84, '2024-01-13'),
(14, 'CatBoost', 0.86, '2024-01-14'),
(15, 'GRU', 0.88, '2024-01-15'),
(16, 'Decision Tree', 0.77, '2024-01-16'),
(17, 'Bayesian Ridge', 0.79, '2024-01-17'),
(18, 'ElasticNet', 0.74, '2024-01-18'),
(19, 'Ridge Regression', 0.76, '2024-01-19'),
(20, 'Linear SVC', 0.81, '2024-01-20');

-- %%
select count(1) from ${catalogo}.exploratory.PRUEBAS_MODELOS_EXT

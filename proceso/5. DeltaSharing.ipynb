-- %%
select * from catalog_empresa.golden.player_attributes

-- %%
CREATE SHARE player_share

-- %%
SHOW SHARES

-- %%
ALTER SHARE player_share 
ADD TABLE catalog_empresa.golden.player_attributes
WITH HISTORY

-- %%
CREATE RECIPIENT player_attributes_rec

-- %%
GRANT SELECT 
ON SHARE player_share
TO RECIPIENT player_attributes_rec
